# %% [markdown]
# # String Operations in SQL

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2

conn = psycopg2.connect("dbname=northwind user=postgres password=password host=localhost port=5433")

# %% [markdown]
# ### Display products whose Quantity per Unit contains the string 'kg'

# %%
# Like is used for string matching

sql = """
SELECT * 
FROM products
WHERE "QuantityPerUnit" LIKE '%kg%'
"""

data = sqlio.read_sql_query(sql, conn)
data.head(10)
# Out:
#    ProductID                      ProductName  SupplierID  CategoryID  \
# 0          7  Uncle Bob's Organic Dried Pears           3           7
# 1          9                  Mishi Kobe Niku           4           6
# 2         11                   Queso Cabrales           5           4
# 3         12        Queso Manchego La Pastora           5           4
# 4         13                            Konbu           6           8
# 5         14                             Tofu           6           7
# 6         17                     Alice Mutton           7           6
# 7         18                 Carnarvon Tigers           7           8
# 8         21              Sir Rodney's Scones           8           3
# 9         22              Gustaf's Knäckebröd           9           5
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0      12 - 1 lb pkgs.      30.00            15             0            10
# 1     18 - 500 g pkgs.      97.00            29             0             0
# 2            1 kg pkg.      21.00            22            30            30
# 3     10 - 500 g pkgs.      38.00            86             0             0
# 4             2 kg box       6.00            24             0             5
# 5     40 - 100 g pkgs.      23.25            35             0             0
# 6       20 - 1 kg tins      39.00             0             0             0
# 7           16 kg pkg.      62.50            42             0             0
# 8  24 pkgs. x 4 pieces      10.00             3            40             5
# 9     24 - 500 g pkgs.      21.00           104             0            25
#
#    Discontinued
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0
# 5             0
# 6             1
# 7             0
# 8             0
# 9             0

# %% [markdown]
# ### Display products whose Quantity per Unit contains ONLY the string 'kg'

# %%
sql = """
SELECT * 
FROM products
WHERE "QuantityPerUnit" LIKE '% kg %'
"""

data = sqlio.read_sql_query(sql, conn)
data.head(10)
# Out:
#    ProductID                    ProductName  SupplierID  CategoryID  \
# 0         11                 Queso Cabrales           5           4
# 1         13                          Konbu           6           8
# 2         17                   Alice Mutton           7           6
# 3         18               Carnarvon Tigers           7           8
# 4         42  Singaporean Hokkien Fried Mee          20           5
# 5         44                   Gula Malacca          20           2
# 6         52                       Filo Mix          24           5
# 7         59           Raclette Courdavault          28           4
# 8         69               Gudbrandsdalsost          15           4
# 9         74                  Longlife Tofu           4           7
#
#    QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0        1 kg pkg.      21.00            22            30            30
# 1         2 kg box       6.00            24             0             5
# 2   20 - 1 kg tins      39.00             0             0             0
# 3       16 kg pkg.      62.50            42             0             0
# 4  32 - 1 kg pkgs.      14.00            26             0             0
# 5   20 - 2 kg bags      19.45            27             0            15
# 6  16 - 2 kg boxes       7.00            38             0            25
# 7        5 kg pkg.      55.00            79             0             0
# 8       10 kg pkg.      36.00            26             0            15
# 9        5 kg pkg.      10.00             4            20             5
#
#    Discontinued
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1
# 5             0
# 6             0
# 7             0
# 8             0
# 9             0

# %% [markdown]
# ### Display customers table whose ContactName is transformed into uppercase and CustomerID transformed into lowercase

# %%
sql = """
SELECT upper("ContactName"), lower("CustomerID")
FROM customers
"""

data = sqlio.read_sql_query(sql, conn)
data.head(10)
# Out:
#                 upper  lower
# 0        MARIA ANDERS  alfki
# 1        ANA TRUJILLO  anatr
# 2      ANTONIO MORENO  anton
# 3        THOMAS HARDY  arout
# 4  CHRISTINA BERGLUND  bergs
# 5          HANNA MOOS  blaus
# 6  FRéDéRIQUE CITEAUX  blonp
# 7       MARTíN SOMMER  bolid
# 8    LAURENCE LEBIHAN  bonap
# 9   ELIZABETH LINCOLN  bottm
